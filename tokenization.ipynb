# %%
text="What is my name?"

# %%
import tiktoken as t

# %%
tokenizer=t.encoding_for_model(model_name="gpt-4")

# %%
tId=tokenizer.encode(text)
tId
# [3923, 374, 856, 836, 30]
# Out:
# [3923, 374, 856, 836, 30]

# %%
# My Name is Muhammad Noman :).
resultId=[5159, 4076, 374, 36831, 452, 7053, 551, 570]
result=tokenizer.decode(resultId)
result
# Out:
# 'My Name is Muhammad Noman :).'
